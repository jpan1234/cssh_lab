# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas import Series
import calendar
import matplotlib as mpl
import matplotlib.pyplot as plt
#NECESSARY FOR XTICKS OPTION, ETC.
from pylab import*
# %matplotlib inline
import seaborn as sns
import datetime

# %%
#Set PANDAS to show all columns in DataFrame
pd.set_option('display.max_columns', None)
#The following line will set the defalt plots to be bigger
plt.rcParams['figure.figsize'] = (15, 5)

# %%
data= pd.read_csv('./from@UAW_alltweets_july 2022.csv')
data
# Out:
#                     created_at  \
# 0     2022-06-28T13:59:42.000Z
# 1     2022-06-27T16:44:47.000Z
# 2     2022-06-24T21:34:33.000Z
# 3     2022-06-21T14:13:11.000Z
# 4     2022-06-19T14:03:56.000Z
# ...                        ...
# 9329  2011-01-18T15:58:18.000Z
# 9330  2011-01-18T15:57:36.000Z
# 9331  2011-01-14T18:45:08.000Z
# 9332  2011-01-06T15:10:41.000Z
# 9333  2010-12-15T20:58:24.000Z
#
#                                                    text  \
# 0     Union members and family members save up to 30...
# 1     As workers fight to organize or strike for bet...
# 2     Our union has historically fought for equal ac...
# 3     Statement on changes to COVID-19 Protocols aft...
# 4     UAW PRESIDENT RAY CURRY STATEMENT ON JUNETEENT...
# ...                                                 ...
# 9329  New post: Video: Bob King highlights President...
# 9330  New post: Video: Bob King discusses union dens...
# 9331  New post: UAW political activists to gather in...
# 9332  New post: Sign the petition: Tell NFL owners n...
# 9333  New post: UAW and Caterpillar Inc. begin contr...
#
#                                                entities  \
# 0     {'urls': [{'start': 175, 'end': 198, 'url': 'h...
# 1     {'urls': [{'start': 257, 'end': 280, 'url': 'h...
# 2     {'urls': [{'start': 251, 'end': 274, 'url': 'h...
# 3     {'urls': [{'start': 86, 'end': 109, 'url': 'ht...
# 4     {'urls': [{'start': 250, 'end': 273, 'url': 'h...
# ...                                                 ...
# 9329  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9330  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9331  {'annotations': [{'start': 47, 'end': 56, 'pro...
# 9332  {'annotations': [{'start': 34, 'end': 36, 'pro...
# 9333  {'annotations': [{'start': 10, 'end': 33, 'pro...
#
#                                          public_metrics
# 0     {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 1     {'retweet_count': 16, 'reply_count': 8, 'like_...
# 2     {'retweet_count': 41, 'reply_count': 9, 'like_...
# 3     {'retweet_count': 2, 'reply_count': 3, 'like_c...
# 4     {'retweet_count': 8, 'reply_count': 5, 'like_c...
# ...                                                 ...
# 9329  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 9330  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 9331  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 9332  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 9333  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
# [9334 rows x 4 columns]

# %%
#create new DataFrame and only keep 'text', 'entities' and 'created_at' columns
#drop the unnamed column
df = data[['created_at','text','entities','public_metrics']]
df
# Out:
#                     created_at  \
# 0     2022-06-28T13:59:42.000Z
# 1     2022-06-27T16:44:47.000Z
# 2     2022-06-24T21:34:33.000Z
# 3     2022-06-21T14:13:11.000Z
# 4     2022-06-19T14:03:56.000Z
# ...                        ...
# 9329  2011-01-18T15:58:18.000Z
# 9330  2011-01-18T15:57:36.000Z
# 9331  2011-01-14T18:45:08.000Z
# 9332  2011-01-06T15:10:41.000Z
# 9333  2010-12-15T20:58:24.000Z
#
#                                                    text  \
# 0     Union members and family members save up to 30...
# 1     As workers fight to organize or strike for bet...
# 2     Our union has historically fought for equal ac...
# 3     Statement on changes to COVID-19 Protocols aft...
# 4     UAW PRESIDENT RAY CURRY STATEMENT ON JUNETEENT...
# ...                                                 ...
# 9329  New post: Video: Bob King highlights President...
# 9330  New post: Video: Bob King discusses union dens...
# 9331  New post: UAW political activists to gather in...
# 9332  New post: Sign the petition: Tell NFL owners n...
# 9333  New post: UAW and Caterpillar Inc. begin contr...
#
#                                                entities  \
# 0     {'urls': [{'start': 175, 'end': 198, 'url': 'h...
# 1     {'urls': [{'start': 257, 'end': 280, 'url': 'h...
# 2     {'urls': [{'start': 251, 'end': 274, 'url': 'h...
# 3     {'urls': [{'start': 86, 'end': 109, 'url': 'ht...
# 4     {'urls': [{'start': 250, 'end': 273, 'url': 'h...
# ...                                                 ...
# 9329  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9330  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9331  {'annotations': [{'start': 47, 'end': 56, 'pro...
# 9332  {'annotations': [{'start': 34, 'end': 36, 'pro...
# 9333  {'annotations': [{'start': 10, 'end': 33, 'pro...
#
#                                          public_metrics
# 0     {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 1     {'retweet_count': 16, 'reply_count': 8, 'like_...
# 2     {'retweet_count': 41, 'reply_count': 9, 'like_...
# 3     {'retweet_count': 2, 'reply_count': 3, 'like_c...
# 4     {'retweet_count': 8, 'reply_count': 5, 'like_c...
# ...                                                 ...
# 9329  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 9330  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 9331  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 9332  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 9333  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
# [9334 rows x 4 columns]

# %%
df=df.drop_duplicates(['text'], keep='last')
df=df.dropna(subset = ['entities'])
df
# Out:
#                     created_at  \
# 0     2022-06-28T13:59:42.000Z
# 1     2022-06-27T16:44:47.000Z
# 2     2022-06-24T21:34:33.000Z
# 3     2022-06-21T14:13:11.000Z
# 4     2022-06-19T14:03:56.000Z
# ...                        ...
# 9329  2011-01-18T15:58:18.000Z
# 9330  2011-01-18T15:57:36.000Z
# 9331  2011-01-14T18:45:08.000Z
# 9332  2011-01-06T15:10:41.000Z
# 9333  2010-12-15T20:58:24.000Z
#
#                                                    text  \
# 0     Union members and family members save up to 30...
# 1     As workers fight to organize or strike for bet...
# 2     Our union has historically fought for equal ac...
# 3     Statement on changes to COVID-19 Protocols aft...
# 4     UAW PRESIDENT RAY CURRY STATEMENT ON JUNETEENT...
# ...                                                 ...
# 9329  New post: Video: Bob King highlights President...
# 9330  New post: Video: Bob King discusses union dens...
# 9331  New post: UAW political activists to gather in...
# 9332  New post: Sign the petition: Tell NFL owners n...
# 9333  New post: UAW and Caterpillar Inc. begin contr...
#
#                                                entities  \
# 0     {'urls': [{'start': 175, 'end': 198, 'url': 'h...
# 1     {'urls': [{'start': 257, 'end': 280, 'url': 'h...
# 2     {'urls': [{'start': 251, 'end': 274, 'url': 'h...
# 3     {'urls': [{'start': 86, 'end': 109, 'url': 'ht...
# 4     {'urls': [{'start': 250, 'end': 273, 'url': 'h...
# ...                                                 ...
# 9329  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9330  {'annotations': [{'start': 17, 'end': 24, 'pro...
# 9331  {'annotations': [{'start': 47, 'end': 56, 'pro...
# 9332  {'annotations': [{'start': 34, 'end': 36, 'pro...
# 9333  {'annotations': [{'start': 10, 'end': 33, 'pro...
#
#                                          public_metrics
# 0     {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 1     {'retweet_count': 16, 'reply_count': 8, 'like_...
# 2     {'retweet_count': 41, 'reply_count': 9, 'like_...
# 3     {'retweet_count': 2, 'reply_count': 3, 'like_c...
# 4     {'retweet_count': 8, 'reply_count': 5, 'like_c...
# ...                                                 ...
# 9329  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 9330  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 9331  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 9332  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 9333  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
# [9334 rows x 4 columns]

# %%
df = df.set_index(['created_at'])
df.head(2)
# Out:
#                                                                        text  \
# created_at
# 2022-06-28T13:59:42.000Z  Union members and family members save up to 30...
# 2022-06-27T16:44:47.000Z  As workers fight to organize or strike for bet...
#
#                                                                    entities  \
# created_at
# 2022-06-28T13:59:42.000Z  {'urls': [{'start': 175, 'end': 198, 'url': 'h...
# 2022-06-27T16:44:47.000Z  {'urls': [{'start': 257, 'end': 280, 'url': 'h...
#
#                                                              public_metrics
# created_at
# 2022-06-28T13:59:42.000Z  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 2022-06-27T16:44:47.000Z  {'retweet_count': 16, 'reply_count': 8, 'like_...

# %% [markdown]
# # keywords only

# %%
searchfor= ['climate','climates','climatic','climatology','climatologist','climate-science','1.5 degree','1.5°C','1.5 degrees',
            '2 degree','2°C','two degree','two degrees','warming','heating','burning','heat','heatwave','dangerous heat',
            'temperature','heat pumps','cooling','tipping point','tipping points','arctic','arctic drilling','drilling',
            'transition','transitions','transitioned','transitioning','transformation','transformations','transformed',
            'transforming','decarbonize','decarbonization','decarbonized','decarbonizing','decarbonizes','sustainable',
            'sustainability','unsustainable','sustain','sustained','sustains','emit','emission','emissions','emits',
            'emitting','emitted','greenhouse','ghg','ghgs','zero','net zero','net-zero','zero net','zero-net','zero-carbon',
            'low-carbon','lower-carbon','high-carbon','low-emissions','lower-emissions','carbon-offset','carbon-offsets',
            'high-emissions','energy','high-energy','low-energy','clean-energy','green-energy','electric','electricity',
            'battery-electric','electrical','electric vehicle','electric vehicles','electric-vehicle','EV','charging',
            'chargers','charger','renewable','renewables','non-renewable','solar','solarize','rooftop solar','rts','pv',
            'photovoltaic','wind','turbine','turbines','off-shore','offshore','hydropower','hydro','water','hydraulic',
            'hydrogen','ocean energy','wave energy','tidal energy','geothermal','biofuel','bio-fuels','biofuels','bio-fuels',
            'biopower','bioenergy','bio-energy','bioenergies','bio-energies','biomass','bio-mass','geoengineering',
            'orsted','iberdrola','jinkosolar holding','vestas wind systems','siemens gamesa renewable energy',
            'Brookfield Renewable Partners LP','First Solar','Canadian Solar','Renewable Energy Group','SunPower',
            'utility','utilities','green new deal','gnd','new deal','green','greener','greening',
            'green-energy','greens','environment','environmental','environments','environmentalist','anti-environment',
            'antienvironment','environment-friendly','environmentally','environmentalism','nature','abate','abates',
            'abatement','abating','ecosystem','ecology','ecologist','ecological','eco-friendly','eco-socialism',
            'ecosocialism','ecosocialist','battery','battery-power','battery-powered','battery-storage','intensity',
            'energy transmission','electricity transmission','transmission lines','energy distribution',
            'energy-distribution','siting','pollution','pollute','polluter','pollutes','polluted','polluting','carbon-tax',
            'carbon fee','carbon-fee','revenue recycling','fee and dividend','renewable-subsidy','recycle','oil','gas','coal',
            'natural gas','lng','fossil fuel','fossil fuels','fuel','frack','fracking','fracturing','fracked','fracks',
            'ccs','carbon capture and storage','direct air capture','carbon capture and reuse','ccr','carbon capture and utilization',
            'ccu','methane','ch4','carbon','co2','carbon-capture','carbon-technology','mine','mining','mined','mines','extract',
            'extracted','extracts','extracting','extraction','nuclear','nuke','nukes','BP','Exxon','ExxonMobil','Shell',
            'TotalEnergies','lithium','lithium-ion','natural resource','natural resources','plastic','plastics','pipeline',
            'pipelines','keystone','dakota access','standing rock','Intergovernmental Panel on Climate Change','ipcc',
            'Oil and Gas Climate Initiative','OGCI','Paris','United Nations Framing Convention on Climate Change','UNFCCC',
            'Build Back Better','BBB','sunrise','extinction rebellion','clean air act','caa','clean air','clean power plan',
            'cpp','environmental protection agency','epa','dep','federal emergency management agency','fema','job retraining',
            'conference of parties','cop','united nations climate change conference','cop21','cop22','cop23','cop24','cop25',
            'cop26','paris agreement','paris climate accords','earth day','earthday','earth','planet','sdg','sdgs','sdg13',
            'sdg7','justice40','extreme weather','natural disaster','natural disasters','flood','flooding','flooded',
            'floods','hurricane','hurricanes','wildfire','wildfires','drought','droughts','esg','csr','fridays for future','f4f',
            'divest','divestment','divesting','retrofit','retrofitting','retrofits','retrofitted','health and safety']

# %%
def filter_tweets_with_keywords(df, keywords):
    def match_with_pattern(key, text):
        if key.lower() in text.lower():
            return True
        else:
            return False
    
    def match_with_token(key, text):
        token_list = re.split("[.,?#]| ", text.lower())
        if key.lower() in token_list:
            return True
        else:
            return False
    
    # save the index results
    index_list = []
    for it in df.iterrows():  # loop every row
        flag = False  # init the flag with False;
        text = it[1].text  # extract the text string
        for key in keywords:  # check if a keyword exists
            if len(key.lower().split(" ")) == 1:
                flag = match_with_token(key, text)
            else:
                flag = match_with_pattern(key, text)
            
            if flag:
                break
        # save the list
        index_list.append(flag)
        
    return index_list


res_index_list_keywords = filter_tweets_with_keywords(df, searchfor)

# %%
res_index_ser_keywords = pd.Series(res_index_list_keywords, index=df.index)

# %%
df = df[res_index_ser_keywords]
df
# Out:
#                                                                        text  \
# created_at
# 2022-05-05T17:43:46.000Z  We want green trucks, but we do not want the u...
# 2022-04-28T16:04:42.000Z  USPS has failed to invest in good union jobs a...
# 2022-04-22T13:00:17.000Z  Now an International event, Earth Day has been...
# 2022-04-12T13:00:14.000Z  Today in 1934, workers at Electric Auto-Lite C...
# 2022-04-06T19:03:12.000Z  UAW leaders and activists delivered thousands ...
# ...                                                                     ...
# 2011-09-25T12:00:17.000Z  At @NBC studio in Detroit with @uawlocal900 Pr...
# 2011-08-31T23:25:45.000Z  Want a good #jobs and a clean #environment, he...
# 2010-10-12T19:55:29.000Z  D'Arcinoff Group receives funding for alternat...
# 2010-08-26T17:15:09.000Z  New from UAW: Workers vote for UAW at Johnson ...
# 2011-07-29T13:57:55.000Z  New post: BlueGreen Alliance supports administ...
#
#                                                                    entities  \
# created_at
# 2022-05-05T17:43:46.000Z  {'urls': [{'start': 137, 'end': 160, 'url': 'h...
# 2022-04-28T16:04:42.000Z  {'annotations': [{'start': 0, 'end': 3, 'proba...
# 2022-04-22T13:00:17.000Z  {'hashtags': [{'start': 219, 'end': 228, 'tag'...
# 2022-04-12T13:00:14.000Z  {'hashtags': [{'start': 278, 'end': 282, 'tag'...
# 2022-04-06T19:03:12.000Z  {'urls': [{'start': 265, 'end': 288, 'url': 'h...
# ...                                                                     ...
# 2011-09-25T12:00:17.000Z  {'hashtags': [{'start': 97, 'end': 102, 'tag':...
# 2011-08-31T23:25:45.000Z  {'urls': [{'start': 110, 'end': 129, 'url': 'h...
# 2010-10-12T19:55:29.000Z  {'annotations': [{'start': 0, 'end': 15, 'prob...
# 2010-08-26T17:15:09.000Z  {'annotations': [{'start': 31, 'end': 33, 'pro...
# 2011-07-29T13:57:55.000Z  {'annotations': [{'start': 10, 'end': 27, 'pro...
#
#                                                              public_metrics
# created_at
# 2022-05-05T17:43:46.000Z  {'retweet_count': 5, 'reply_count': 2, 'like_c...
# 2022-04-28T16:04:42.000Z  {'retweet_count': 53, 'reply_count': 8, 'like_...
# 2022-04-22T13:00:17.000Z  {'retweet_count': 30, 'reply_count': 0, 'like_...
# 2022-04-12T13:00:14.000Z  {'retweet_count': 115, 'reply_count': 2, 'like...
# 2022-04-06T19:03:12.000Z  {'retweet_count': 6, 'reply_count': 3, 'like_c...
# ...                                                                     ...
# 2011-09-25T12:00:17.000Z  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 2011-08-31T23:25:45.000Z  {'retweet_count': 5, 'reply_count': 0, 'like_c...
# 2010-10-12T19:55:29.000Z  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2010-08-26T17:15:09.000Z  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2011-07-29T13:57:55.000Z  {'retweet_count': 1, 'reply_count': 0, 'like_c...
#
# [231 rows x 3 columns]

# %%
df.to_csv('./from@UAW_climate_tweets_0801.csv')
